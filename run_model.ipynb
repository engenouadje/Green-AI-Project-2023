# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Green AI/project/yolov5-master
# Out:
# /content/drive/.shortcut-targets-by-id/1ZGDp4m1XnkL-zvtIhD_ZuNw_YxzufBjC/Green AI/project/yolov5-master

# %% [markdown]
# # 1. Configuration

# %% [markdown]
# ## Run train.py, change parameters in train.py :
# ### 1. train.py :
# - model = https://docs.ultralytics.com/yolov5/tutorials/train_custom_data/ \\
# - epochs = how many times the entire training dataset is passed forward and  backward through the neural network. \\
# - batch-size = defines the number of samples (or images) that are processed in - one iteration during each epoch.
#
# ### 2. Configure datatrain.yaml :
#
# path: /content/drive/MyDrive/Green AI/project/Dataset  # dataset root dir
# train: train/images
# val: valid/images
# test: test/images # test images (optional)
#
# Classes <br />
# names:
#   0: ""
# ### 3. Configure detect.py :
# - model = change the exp you want
# - change path for the test images
# - or detect.py --source video.mp4, video must be in yolo master folder

# %% [markdown]
# ### If you want to train during a very long time, keep colab open with this input in console:
# function ClickConnect(){ \\
# console.log(\"Clicked on connect button\"); \\
# document.querySelector(\"colab-connect-button\").click() \\
# } \\
# setInterval(ClickConnect,60000)

# %% [markdown]
# # 2. Train

# %% [markdown]
# ## First Run:
# Run default config, we set it like this :
# - model = yolo5 small version
# - epochs = 10
# - batch size = 16 \\
# First training model is located in runs/exp \\
# Take 20 minutes to run

# %%
# !python train.py
# Out:
# 2023-12-01 11:14:20.834695: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 11:14:20.834756: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 11:14:20.834796: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Second Run:
# Run with new config  :
# - model = yolo5 xl version
# - epochs = 100
# - batch size = 16 \\
# First training model is located in runs/exp \\
# Take 2h and 40 minutes to run \\
# If you want to run don't forget to add autoclick with js injection !

# %%
# !python 'train.py' --batch 16 --epochs 100  --cfg ./models/yolov5l.yaml --weights ''
# Out:
# 2023-12-01 13:38:16.100243: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 13:38:16.100296: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 13:38:16.100338: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # 3. Detect

# %% [markdown]
# ## First model exp

# %% [markdown]
# ### cannes.mp4

# %%
# !python detect.py --source cannes.mp4
# Out:
# detect: weights=/content/drive/MyDrive/Green AI/project/yolov5-master/runs/train/exp/weights/best.pt, source=cannes.mp4, data=data/datatrain.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-11-23 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2277) /content/drive/.shortcut-targets-by-id/1ZGDp4m1XnkL-zvtIhD_ZuNw_YxzufBjC/Green AI/project/yolov5-master/cannes.mp4: 480x640 1 , 44.3ms
# ...

# %% [markdown]
# ### bali.mp4

# %%
# !python detect.py --source bali.mp4
# Out:
# detect: weights=/content/drive/MyDrive/Green AI/project/yolov5-master/runs/train/exp/weights/best.pt, source=bali.mp4, data=data/datatrain.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-11-23 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/4615) /content/drive/.shortcut-targets-by-id/1ZGDp4m1XnkL-zvtIhD_ZuNw_YxzufBjC/Green AI/project/yolov5-master/bali.mp4: 384x640 (no detections), 58.8ms
# ...

# %% [markdown]
# ### Test dataset

# %%
#images of test
# !python detect.py --save-txt
# Out:
# detect: weights=/content/drive/MyDrive/Green AI/project/yolov5-master/runs/train/exp/weights/best.pt, source=/content/drive/MyDrive/Green AI/project/Dataset/test/images, data=data/datatrain.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-11-23 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/613 /content/drive/.shortcut-targets-by-id/1ZGDp4m1XnkL-zvtIhD_ZuNw_YxzufBjC/Green AI/project/Dataset/test/images/13_jpg.rf.66bfb9ab5d1ddcfa48351a275b662de0.jpg: 640x640 1 , 11.6ms
# ...

# %% [markdown]
# ## Second Model

# %% [markdown]
# ### cannes.mp4

# %%
# !python detect2.py --source cannes.mp4
# Out:
# detect2: weights=/content/drive/MyDrive/Green AI/project/yolov5-master/runs/train/exp2/weights/best.pt, source=cannes.mp4, data=data/datatrain.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-11-23 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# video 1/1 (1/2277) /content/drive/.shortcut-targets-by-id/1ZGDp4m1XnkL-zvtIhD_ZuNw_YxzufBjC/Green AI/project/yolov5-master/cannes.mp4: 480x640 (no detections), 53.6ms
# ...

# %% [markdown]
# ### bali.mp4

# %%
# !python detect2.py --source bali.mp4
# Out:
# detect2: weights=/content/drive/MyDrive/Green AI/project/yolov5-master/runs/train/exp2/weights/best.pt, source=bali.mp4, data=data/datatrain.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-11-23 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# video 1/1 (1/4615) /content/drive/.shortcut-targets-by-id/1ZGDp4m1XnkL-zvtIhD_ZuNw_YxzufBjC/Green AI/project/yolov5-master/bali.mp4: 384x640 (no detections), 52.1ms
# ...

# %% [markdown]
# ### Test dataset

# %%
# !python detect2.py  --save-txt
# Out:
# detect2: weights=/content/drive/MyDrive/Green AI/project/yolov5-master/runs/train/exp2/weights/best.pt, source=/content/drive/MyDrive/Green AI/project/Dataset/test/images, data=data/datatrain.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-11-23 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# image 1/613 /content/drive/.shortcut-targets-by-id/1ZGDp4m1XnkL-zvtIhD_ZuNw_YxzufBjC/Green AI/project/Dataset/test/images/13_jpg.rf.66bfb9ab5d1ddcfa48351a275b662de0.jpg: 640x640 1 , 49.1ms
# ...
